# %% [markdown]
# # Exploratory Data Analysis – NDIS Cost Forecasting Optimizer
#
# This notebook provides a high-level overview of participant spending patterns, support categories, and potential cost anomalies based on simulated NDIS-style data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('simulated_ndis_data.csv')
df.head()
# Out:
#    participant_id  age  gender region disability_type   support_category  \
# 0               1   56    Male    VIC    Neurological  Capacity Building
# 1               2   19  Female    ACT    Intellectual  Capacity Building
# 2               3   65  Female     NT          Autism  Capacity Building
# 3               4   25  Female     WA    Intellectual  Capacity Building
# 4               5   28  Female     NT    Neurological  Capacity Building
#
#    monthly_spend service_provider  planned_cost intervention    month
# 0        1805.77       Provider B       1764.01           No  2023-09
# 1        2542.23       Provider D       2832.25           No  2023-11
# 2        4635.12       Provider C       4387.03           No  2023-12
# 3        4459.03       Provider E       4713.28          Yes  2023-11
# 4        4983.22       Provider E       4851.36          Yes  2023-06

# %% [markdown]
# ## Basic Statistics

# %%
df.describe(include='all')
# Out:
#         participant_id          age  gender region      disability_type  \
# count      5000.000000  5000.000000    5000   5000                 5000
# unique             NaN          NaN       3      8                    7
# top                NaN          NaN  Female     NT  Developmental delay
# freq               NaN          NaN    2426    679                  744
# mean       2500.500000    37.177400     NaN    NaN                  NaN
# std        1443.520003    18.771926     NaN    NaN                  NaN
# min           1.000000     5.000000     NaN    NaN                  NaN
# 25%        1250.750000    21.000000     NaN    NaN                  NaN
# 50%        2500.500000    37.000000     NaN    NaN                  NaN
# 75%        3750.250000    53.000000     NaN    NaN                  NaN
# max        5000.000000    69.000000     NaN    NaN                  NaN
#
#        support_category  monthly_spend service_provider  planned_cost  \
# ...

# %% [markdown]
# ## Distribution of Monthly Spend

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['monthly_spend'], kde=True, bins=40)
plt.title('Distribution of Monthly Spend')
plt.xlabel('Monthly Spend ($AUD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Spend by Support Category

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='support_category', y='monthly_spend', data=df)
plt.title('Monthly Spend by Support Category')
plt.xlabel('Support Category')
plt.ylabel('Monthly Spend ($AUD)')
plt.show()
